# %%
import pickle

# %%
with open('denseOutput.pkl', 'rb') as f:
    rawList = pickle.load(f)

# %%
rawList
# Out:
# [[array([[2.6971512e+00, 2.7086098e+00, 2.6993246e+00, ..., 8.5541048e+00,
#           8.4723778e+00, 8.3603067e+00],
#          [2.6992977e+00, 2.7116864e+00, 2.7080491e+00, ..., 8.5622768e+00,
#           8.4427032e+00, 8.2768679e+00],
#          [2.6744485e+00, 2.6835737e+00, 2.6827703e+00, ..., 8.5610638e+00,
#           8.3874741e+00, 8.1730042e+00],
#          ...,
#          [4.1205123e-02, 5.4480609e-02, 7.9175852e-02, ..., 1.0326074e+00,
#           1.0460013e+00, 1.0915695e+00],
#          [7.0304647e-03, 9.7657360e-02, 1.4058178e-02, ..., 6.3365567e-01,
#           5.7047141e-01, 5.3643221e-01],
#          [8.7137274e-02, 1.9367391e-02, 8.3893783e-02, ..., 2.8658736e-01,
#           1.6892368e-01, 1.2893985e-01]], dtype=float32),
#   array([[2.0091162 , 2.0166519 , 2.013114  , ..., 2.1154919 , 2.1159115 ,
#           2.1164324 ],
#          [2.007424  , 2.015529  , 2.016577  , ..., 2.114041  , 2.1147997 ,
#           2.115577  ],
# ...
